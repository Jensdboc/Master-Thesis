# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest 
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import LinearSVC

from sklearn.model_selection import learning_curve

# %%
path = "train/"
df_train = pd.read_csv(path + "all_keypoints.csv", delimiter=";")
x_train = df_train.iloc[:, 2:].to_numpy()
y_train = df_train["class"]
y_train.to_numpy()

path = "valid/"
df_val = pd.read_csv(path + "all_keypoints.csv", delimiter=";")
x_val = df_val.iloc[:, 2:].to_numpy()
y_val = df_val["class"].to_numpy()

path = "test/"
df_test = pd.read_csv(path + "all_keypoints.csv", delimiter=";")
x_test = df_test.iloc[:, 2:].to_numpy()
y_test = df_test["class"].to_numpy()

x = np.vstack((x_train, x_val))
y = np.hstack((y_train, y_val))

df_train.head()
# Out:
#                                             filename      class         0  \
# 0  img_001647_jpg.rf.6b8b57b958ca1129df2b07b0894f...    Engaged  0.477401
# 1  img_000817_jpg.rf.418da3f3899c4004dd2961accf20...  Confusion  0.463258
# 2  img_001714_jpg.rf.704d452be060f91f9aab1a9f446f...    Engaged  0.490912
# 3  img_001799_jpg.rf.a87b792d3617f2fa31fc6dc8c7f1...    Engaged  0.437817
# 4  img_000920_jpg.rf.57454afbde7e52cb275e3a894804...    Boredom  0.656678
#
#           1         2         3         4         5         6         7  ...  \
# 0  0.689527 -0.015054  0.484492  0.659317 -0.041307  0.480034  0.665531  ...
# 1  0.679552 -0.021432  0.457595  0.643239 -0.047642  0.460066  0.652895  ...
# 2  0.703257 -0.013543  0.493603  0.671547 -0.042487  0.492077  0.677883  ...
# 3  0.490217 -0.020038  0.433354  0.450080 -0.040992  0.436644  0.460370  ...
# 4  0.872208 -0.011119  0.657698  0.842539 -0.042086  0.659062  0.848852  ...
#
#        1394      1395      1396      1397      1398      1399      1400  \
# 0 -0.003646  0.498314  0.594094 -0.009697  0.541923  0.585931  0.012465
# 1 -0.004534  0.470298  0.576350 -0.010996  0.521273  0.559552  0.001972
# 2 -0.008459  0.508832  0.602887 -0.014218  0.556645  0.589489  0.001887
# 3 -0.005381  0.452863  0.375091 -0.010293  0.504004  0.356637 -0.001960
# 4 -0.014668  0.687215  0.774991 -0.019777  0.742931  0.770813 -0.009770
#
#        1401      1402  Unnamed: 1405
# 0  0.545758  0.582824       0.012944
# 1  0.526257  0.555053       0.001506
# 2  0.560268  0.586643       0.001647
# 3  0.509774  0.350223      -0.002576
# 4  0.748287  0.766542      -0.010310
#
# [5 rows x 1406 columns]

# %%
def plot_learning_curve(sizes,train,val):
    train_scores_mean = np.mean(train, axis=1)
    train_scores_std = np.std(train, axis=1)
    val_scores_mean = np.mean(val, axis=1)
    val_scores_std = np.std(val, axis=1)

    _, axes = plt.subplots(1,)
    axes.grid()
    axes.fill_between(
        sizes,
        train_scores_mean - train_scores_std,
        train_scores_mean + train_scores_std,
        alpha=0.1,
        color="g",
    )
    axes.fill_between(
        sizes,
        val_scores_mean - val_scores_std,
        val_scores_mean + val_scores_std,
        alpha=0.1,
        color="r",
    )
    axes.plot(
        sizes, train_scores_mean, "o-", color="g", label="Training score"
    )
    axes.plot(
        sizes, val_scores_mean, "o-", color="r", label="Cross-validation score"
    )
    axes.legend(loc="best")
    
    plt.title("Training and Validation Accuracy Curves")
    plt.xlabel('Fold')
    plt.ylabel('Accuracy')
    plt.show()
    return

# %%
n_folds = 10 # Max 15 folds
cv = KFold(n_splits=n_folds, shuffle=True, random_state=42)

# %%
# create the pipeline:
preprocessing = Pipeline([('pp', Normalizer())]) 

# Feature selection, you can also try others
feature_selection = Pipeline([('selectkbest', SelectKBest())])  

classifier = Pipeline([('clf', LinearSVC(dual="auto"))])

pipe = Pipeline([
    ('preprocessing', preprocessing),
    ('feature_selection', feature_selection),
    ('classifier', classifier)])

# You may need to specify other hyperparameters here if you investigate other blocks
k_grid = [10,1000,1404]
C_grid = [1,10,1000]

# And make sure to add them to your param_grid
param_grid = {
    'feature_selection__selectkbest__k' : k_grid,
    'classifier__clf__C' : C_grid,
}

# define GridSearchCV object
gridsearch = GridSearchCV(pipe, param_grid, n_jobs=8, cv=cv, verbose=3, return_train_score=True)

# Train the pipeline
gridsearch.fit(x,y)
# Out:
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessing',
#                                         Pipeline(steps=[('pp', Normalizer())])),
#                                        ('feature_selection',
#                                         Pipeline(steps=[('selectkbest',
#                                                          SelectKBest())])),
#                                        ('classifier',
#                                         Pipeline(steps=[('clf',
#                                                          LinearSVC(dual='auto'))]))]),
#              n_jobs=8,
#              param_grid={'classifier__clf__C': [1, 10, 1000],
#                          'feature_selection__selectkbest__k': [10, 1000, 1404]},
#              return_train_score=True, verbose=3)
# [CV 1/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.308, test=0.331) total time=   0.4s
# [CV 4/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.415, test=0.412) total time=   5.8s
# [CV 2/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.631, test=0.365) total time=   9.7s
# [CV 1/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.313, test=0.337) total time=   0.4s
# [CV 5/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.313, test=0.333) total time=   0.3s
# [CV 9/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.310, test=0.345) total time=   0.3s
# [CV 3/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.445, test=0.404) total time=   8.7s
# [CV 9/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.447, test=0.395) total time=   8.4s
# [CV 7/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.677, test=0.328) total time=  15.5s
# [CV 6/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.588, test=0.542) total time=  25.9s
# [CV 5/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.756, test=0.412) total time= 3.8min
# [CV 2/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.301, test=0.287) total time=   0.4s
# [CV 5/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.413, test=0.418) total time=   6.2s
# [CV 6/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.640, test=0.395) total time=   9.9s
# [CV 6/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.318, test=0.271) total time=   0.3s
# [CV 10/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.315, test=0.294) total time=   0.3s
# [CV 4/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.436, test=0.463) total time=   8.8s
# [CV 2/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.686, test=0.388) total time=  14.4s
# [CV 9/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.691, test=0.373) total time=  14.2s
# [CV 7/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.565, test=0.542) total time=  20.9s
# [CV 6/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.764, test=0.395) total time= 3.8min
# [CV 4/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.289, test=0.282) total time=   0.4s
# [CV 6/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.406, test=0.429) total time=   5.9s
# [CV 3/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.639, test=0.410) total time=   9.4s
# [CV 10/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.640, test=0.356) total time=   9.6s
# [CV 8/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.442, test=0.412) total time=   8.7s
# [CV 6/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.687, test=0.384) total time=  14.2s
# [CV 4/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.580, test=0.571) total time=  21.8s
# [CV 1/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.761, test=0.399) total time= 4.0min
# [CV 6/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.313, test=0.277) total time=   0.3s
# [CV 7/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.409, test=0.424) total time=   6.1s
# [CV 5/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.633, test=0.322) total time=   9.6s
# [CV 3/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.317, test=0.309) total time=   0.3s
# [CV 7/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.310, test=0.350) total time=   0.3s
# [CV 1/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.440, test=0.404) total time=   8.9s
# [CV 10/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.444, test=0.441) total time=   9.3s
# [CV 8/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.669, test=0.407) total time=  14.5s
# [CV 5/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.580, test=0.559) total time=  23.8s
# [CV 3/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.767, test=0.444) total time= 4.0min
# [CV 5/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.298, test=0.316) total time=   0.3s
# [CV 1/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.409, test=0.399) total time=   5.9s
# [CV 9/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.413, test=0.373) total time=   5.9s
# [CV 8/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.633, test=0.424) total time=   9.4s
# [CV 6/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.437, test=0.446) total time=   9.3s
# [CV 4/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.677, test=0.446) total time=  14.5s
# [CV 3/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.421, test=0.365) total time=   0.4s
# [CV 5/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.414, test=0.441) total time=   0.4s
# [CV 7/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.412, test=0.424) total time=   0.4s
# [CV 9/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.417, test=0.395) total time=   0.4s
# [CV 1/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.578, test=0.522) total time=  20.9s
# [CV 10/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.571, test=0.514) total time=  22.7s
# [CV 7/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.752, test=0.435) total time= 3.8min
# [CV 7/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.296, test=0.339) total time=   0.3s
# [CV 10/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.313, test=0.282) total time=   0.3s
# [CV 3/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.420, test=0.393) total time=   5.7s
# [CV 10/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.413, test=0.429) total time=   5.8s
# [CV 7/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.624, test=0.356) total time=   9.3s
# [CV 5/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.435, test=0.435) total time=   9.0s
# [CV 3/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.680, test=0.416) total time=  14.2s
# [CV 1/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.420, test=0.404) total time=   0.4s
# [CV 2/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.419, test=0.388) total time=   0.4s
# [CV 4/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.419, test=0.446) total time=   0.4s
# [CV 6/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.420, test=0.412) total time=   0.4s
# [CV 8/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.417, test=0.424) total time=   0.4s
# [CV 10/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=10;, score=(train=0.412, test=0.424) total time=   0.4s
# [CV 2/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.576, test=0.551) total time=  19.6s
# [CV 9/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.573, test=0.559) total time=  25.3s
# [CV 8/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.748, test=0.497) total time= 3.9min
# [CV 8/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.301, test=0.282) total time=   0.3s
# [CV 8/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.415, test=0.418) total time=   5.8s
# [CV 4/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.625, test=0.441) total time=   9.3s
# [CV 2/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.317, test=0.287) total time=   0.3s
# [CV 4/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.316, test=0.305) total time=   0.3s
# [CV 8/10] END classifier__clf__C=10, feature_selection__selectkbest__k=10;, score=(train=0.316, test=0.299) total time=   0.3s
# [CV 2/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.444, test=0.416) total time=   8.9s
# [CV 1/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.687, test=0.365) total time=  14.9s
# [CV 10/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.690, test=0.339) total time=  14.3s
# [CV 8/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.580, test=0.571) total time=  20.3s
# [CV 4/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.747, test=0.469) total time= 3.5min
# [CV 9/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.756, test=0.384) total time= 1.8min
# [CV 3/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.302, test=0.303) total time=   0.3s
# [CV 9/10] END classifier__clf__C=1, feature_selection__selectkbest__k=10;, score=(train=0.300, test=0.305) total time=   0.3s
# [CV 2/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1000;, score=(train=0.425, test=0.360) total time=   5.8s
# [CV 1/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.631, test=0.331) total time=   9.4s
# [CV 9/10] END classifier__clf__C=1, feature_selection__selectkbest__k=1404;, score=(train=0.635, test=0.362) total time=   9.6s
# [CV 7/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1000;, score=(train=0.434, test=0.429) total time=   8.7s
# [CV 5/10] END classifier__clf__C=10, feature_selection__selectkbest__k=1404;, score=(train=0.682, test=0.316) total time=  14.4s
# [CV 3/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1000;, score=(train=0.584, test=0.534) total time=  23.9s
# [CV 2/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.760, test=0.404) total time= 3.7min
# [CV 10/10] END classifier__clf__C=1000, feature_selection__selectkbest__k=1404;, score=(train=0.763, test=0.367) total time= 1.8min

# %%
results = gridsearch.cv_results_
train_score = results['mean_train_score'][gridsearch.best_index_]
validation_score = results['mean_test_score'][gridsearch.best_index_]

print('Average training accuracy across folds: {:.3}'.format(train_score))
print('Average validation accuracy across folds: {:.3}'.format(validation_score))

print(gridsearch.best_params_)
# Out:
# Average training accuracy across folds: 0.578
# Average validation accuracy across folds: 0.547
# {'classifier__clf__C': 1000, 'feature_selection__selectkbest__k': 1000}

# %%
best_model = gridsearch.best_estimator_
train_sizes, train_scores, val_scores = learning_curve(best_model, x, y, cv=cv, n_jobs=16, verbose=5)
# Out:
# [learning_curve] Training set sizes: [ 159  518  877 1236 1595]
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   7 out of  50 | elapsed:   43.8s remaining:  4.5min
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done  18 out of  50 | elapsed:  1.4min remaining:  2.6min
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done  29 out of  50 | elapsed:  2.1min remaining:  1.5min
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done  40 out of  50 | elapsed:  2.6min remaining:   39.4s
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done  50 out of  50 | elapsed:  3.0min finished

# %%
plot_learning_curve(train_sizes, train_scores, val_scores)

# %%
# Compute confusion matrix on validation set
best_model.fit(x_train, y_train)
val_predictions = best_model.predict(x_val)
cm = confusion_matrix(y_val, val_predictions)

# Assuming you have class names, replace it with your actual class names or labels
class_names = [str(i) for i in np.unique(y)]

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format=".4g")
plt.title("Confusion Matrix Validation")
plt.show()
# Out:
# [CV] END ..................., score=(train=0.577, test=0.511) total time=  29.4s
# [CV] END ..................., score=(train=0.580, test=0.571) total time=  42.4s
# [CV] END ..................., score=(train=0.342, test=0.237) total time= 1.1min
# [CV] END ..................., score=(train=0.343, test=0.404) total time= 1.7min
# [CV] END ..................., score=(train=0.384, test=0.328) total time=  16.9s
# [CV] END ..................., score=(train=0.453, test=0.277) total time=  16.8s
# [CV] END ..................., score=(train=0.338, test=0.303) total time=  52.7s
# [CV] END ..................., score=(train=0.390, test=0.339) total time=  18.3s
# [CV] END ..................., score=(train=0.428, test=0.271) total time=  17.6s
# [CV] END ..................., score=(train=0.472, test=0.367) total time=  16.5s
# [CV] END ..................., score=(train=0.581, test=0.571) total time=  40.0s
# [CV] END ..................., score=(train=0.584, test=0.534) total time=  46.0s
# [CV] END ..................., score=(train=0.587, test=0.548) total time=  47.5s
# [CV] END ..................., score=(train=0.560, test=0.542) total time=  36.1s
# [CV] END ..................., score=(train=0.570, test=0.517) total time=  26.5s
# [CV] END ..................., score=(train=0.576, test=0.548) total time=  28.4s
# [CV] END ..................., score=(train=0.580, test=0.525) total time=  32.4s
# [CV] END ..................., score=(train=0.315, test=0.294) total time= 1.0min
# [CV] END ..................., score=(train=0.578, test=0.522) total time=  36.0s
# [CV] END ..................., score=(train=0.436, test=0.446) total time= 1.9min
# [CV] END ..................., score=(train=0.421, test=0.393) total time=  53.2s
# [CV] END ..................., score=(train=0.369, test=0.333) total time= 1.1min
# [CV] END ..................., score=(train=0.572, test=0.559) total time=  38.0s
# [CV] END ..................., score=(train=0.428, test=0.326) total time=  17.1s
# [CV] END ..................., score=(train=0.373, test=0.401) total time= 1.1min
# [CV] END ..................., score=(train=0.563, test=0.537) total time=  31.3s
# [CV] END ..................., score=(train=0.580, test=0.492) total time=  25.1s
# [CV] END ..................., score=(train=0.576, test=0.551) total time=  38.3s
# [CV] END ..................., score=(train=0.331, test=0.322) total time= 1.7min
# [CV] END ..................., score=(train=0.332, test=0.315) total time= 1.8min
# [CV] END ..................., score=(train=0.407, test=0.339) total time=  53.0s
# [CV] END ..................., score=(train=0.377, test=0.382) total time= 1.9min
# [CV] END ..................., score=(train=0.573, test=0.514) total time=  30.3s
# [CV] END ..................., score=(train=0.327, test=0.365) total time=   8.3s
# [CV] END ..................., score=(train=0.485, test=0.497) total time= 1.1min
# [CV] END ..................., score=(train=0.429, test=0.379) total time= 1.5min
# [CV] END ..................., score=(train=0.492, test=0.444) total time= 1.1min
# [CV] END ..................., score=(train=0.568, test=0.548) total time=  39.4s
# [CV] END ..................., score=(train=0.517, test=0.362) total time=  41.9s
# [CV] END ..................., score=(train=0.459, test=0.407) total time=  17.1s
# [CV] END ..................., score=(train=0.585, test=0.407) total time=  16.7s
# [CV] END ..................., score=(train=0.582, test=0.559) total time=  42.7s
# [CV] END ..................., score=(train=0.491, test=0.435) total time= 1.3min
# [CV] END ..................., score=(train=0.583, test=0.517) total time=  27.6s
# [CV] END ..................., score=(train=0.579, test=0.542) total time=  33.9s
# [CV] END ..................., score=(train=0.570, test=0.559) total time=  30.2s
# [CV] END ..................., score=(train=0.391, test=0.373) total time= 1.0min
# [CV] END ..................., score=(train=0.371, test=0.303) total time=  11.5s
# [CV] END ..................., score=(train=0.483, test=0.480) total time= 1.9min
# [CV] END ..................., score=(train=0.436, test=0.395) total time=  49.7s
